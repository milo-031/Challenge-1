# %% [markdown]
# ### Importación de datos

# %%
# !pip install folium
import pandas as pd
import matplotlib.pyplot as plt
import folium
from folium.plugins import HeatMap

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()
# Out:
# ...
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# # **Facturación**
# Análisis por tienda: En esta sección se analiza la facturación total por tienda con base en los datos disponibles.

# %%
# Calcular facturación de cada tienda
facturaciones = {
    'Tienda 1': tienda1['Precio'].sum(),
    'Tienda 2': tienda2['Precio'].sum(),
    'Tienda 3': tienda3['Precio'].sum(),
    'Tienda 4': tienda4['Precio'].sum()
}

# Mostrar facturación por tienda
for tienda, total in facturaciones.items():
    print(f"{tienda} facturó: ${total:,.2f}")

# Identificar la tienda con mayor facturación
tienda_mayor = max(facturaciones, key=facturaciones.get)
mayor_valor = facturaciones[tienda_mayor]

print(f"\nLa tienda que más facturó fue: {tienda_mayor} con ${mayor_valor:,.2f}")
# Out:
# Tienda 1 facturó: $1,150,880,400.00
# Tienda 2 facturó: $1,116,343,500.00
# Tienda 3 facturó: $1,098,019,600.00
# Tienda 4 facturó: $1,038,375,700.00
#
# La tienda que más facturó fue: Tienda 1 con $1,150,880,400.00

# %%
# Nombres de las tiendas (eje x)
tiendas = list(facturaciones.keys())

# Valores de facturación (eje y)
valores_facturacion = list(facturaciones.values())

# Crear el gráfico de barras
plt.figure(figsize=(8, 5))
plt.bar(tiendas, valores_facturacion, color='skyblue')

# Añadir título
plt.title('Facturación Total por Tienda')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar los valores encima de cada barra
for i, valor in enumerate(valores_facturacion):
    plt.text(i, valor, f"${valor:,.0f}", ha='center', va='bottom')

plt.yticks([])  # Esto elimina los números del eje Y

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# ```
# # Esto tiene formato de código
# ```
# En el gráfico anterior se puede analizar y observar que la tienda 1, Muestra la facturacion mas alta. Sin embargo, la comparación en el nivel de facturación entre todas las tiendas no es muy elevada.

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Crear diccionario con las tiendas
tiendas = {'Tienda 1': tienda1,
           'Tienda 2': tienda2,
           'Tienda 3': tienda3,
           'Tienda 4': tienda4}

# Imprimir facturación por categoría en cada tienda con formato
for nombre, df in tiendas.items():
    facturacion_categoria = df.groupby('Categoría del Producto')['Precio'].sum()
    print(f"\nFacturación por categoría en {nombre}:")

    for categoria, valor in facturacion_categoria.sort_values(ascending=False).items():
        print(f"  {categoria}: ${valor:,.2f}")

# Crear un DataFrame con la facturación por categoría para cada tienda
facturacion_por_categoria = pd.DataFrame()

for nombre, df in tiendas.items():
    # Agrupar por categoría y sumar la facturación
    facturacion_categoria = df.groupby('Categoría del Producto')['Precio'].sum()
    facturacion_por_categoria[nombre] = facturacion_categoria
# Out:
# Facturación por categoría en Tienda 1:
#   Electrónicos: $429,493,500.00
#   Electrodomésticos: $363,685,200.00
#   Muebles: $187,633,700.00
#   Instrumentos musicales: $91,299,000.00
#   Deportes y diversión: $39,290,000.00
#   Juguetes: $17,995,700.00
#   Artículos para el hogar: $12,698,400.00
#   Libros: $8,784,900.00
#
# Facturación por categoría en Tienda 2:
#   Electrónicos: $410,831,100.00
#   Electrodomésticos: $348,567,800.00
#   Muebles: $176,426,300.00
#   Instrumentos musicales: $104,990,300.00
#   Deportes y diversión: $34,744,500.00
#   Juguetes: $15,945,400.00
#   Artículos para el hogar: $14,746,900.00
#   Libros: $10,091,200.00
#
# Facturación por categoría en Tienda 3:
#   Electrónicos: $410,775,800.00
#   Electrodomésticos: $329,237,900.00
#   Muebles: $201,072,100.00
#   Instrumentos musicales: $77,380,900.00
#   Deportes y diversión: $35,593,100.00
#   Juguetes: $19,401,100.00
#   Artículos para el hogar: $15,060,000.00
#   Libros: $9,498,700.00
#
# ...

# %%
#Crear gráfico de barras agrupadas
ax = facturacion_por_categoria.plot(kind='bar', figsize=(12, 6), colormap='viridis')

# Añadir título y etiquetas
plt.title('Facturación por Categoría en Cada Tienda')
ax.set_xlabel('')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Formatear los valores en el eje Y con comas
ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: f'${x:,.0f}'))

# Ajustar la disposición
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Después de analizar la facturación total por categoría de producto por cada tienda, podemos observar que la categoría Electrónica es la que genera mayores ingresos en todas las tiendas, y libros es la que menos ingresos genera.
#
# Ademas, Electrónica supera a otras categorías en términos de facturación total. Esto se debe a que los productos electrónicos tienen un valor unitario más alto, lo que implica que, aunque la cantidad de ventas no sea tan alta, el precio de cada unidad compensa esta diferencia, generando así ingreso mayores.

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
tiendas = {'Tienda 1': tienda1,
           'Tienda 2': tienda2,
           'Tienda 3': tienda3,
           'Tienda 4': tienda4}

calificaciones_promedio = {}

for nombre, df in tiendas.items():
    promedio_calificacion = df['Calificación'].mean()
    calificaciones_promedio[nombre] = promedio_calificacion
    # Mostrar calificación promedio por tienda
    print(f"Calificación promedio en {nombre}: {promedio_calificacion:.4f}")
# Out:
# Calificación promedio en Tienda 1: 3.9767
# Calificación promedio en Tienda 2: 4.0373
# Calificación promedio en Tienda 3: 4.0483
# Calificación promedio en Tienda 4: 3.9958

# %%
# Crear gráfico de barras horizontales para mostrar la calificación promedio por tienda
plt.figure(figsize=(6, 4))
plt.barh(list(calificaciones_promedio.keys()), list(calificaciones_promedio.values()), color='teal', height=0.5)

# Añadir título
plt.title('Calificación Promedio por Tienda')

# Quitar las etiquetas de los ejes
plt.xlabel('')
plt.ylabel('')

# Añadir la grilla
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Ajustar la disposición
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# El análisis de las calificaciones promedio por tienda muestra que:
#
# Tienda 3 tiene la calificación promedio más alta, con un 4.05.
#
# Tienda 2 sigue de cerca con una calificación promedio de 4.04.
#
# Tienda 4 tiene una calificación de 4.00, que también es bastante alta.
#
# Tienda 1 presenta la calificación promedio más baja con 3.98, pero aún está bastante cerca de las demás.
#
# En general, todas las tiendas tienen calificaciones muy cercanas entre sí, oscilando entre 3.98 y 4.05, lo que indica una valoración bastante positiva por parte de los clientes en general.

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Crear diccionario con las tiendas
tiendas = {
    'Tienda 1': tienda1,
    'Tienda 2': tienda2,
    'Tienda 3': tienda3,
    'Tienda 4': tienda4
}

# Mostrar ventas por categoría, categoría más y menos vendida en cada tienda
for nombre, df in tiendas.items():
    ventas_categoria = df['Categoría del Producto'].value_counts()
    total_ventas = ventas_categoria.sum()  # Total de productos vendidos

    print(f"\nVentas por categoría en {nombre}:\n{ventas_categoria}")

    categoria_mas_vendida = ventas_categoria.idxmax()
    ventas_max = ventas_categoria.max()

    categoria_menos_vendida = ventas_categoria.idxmin()
    ventas_min = ventas_categoria.min()

    print(f"Categoría más vendida: {categoria_mas_vendida} ({ventas_max} ventas)")
    print(f"Categoría menos vendida: {categoria_menos_vendida} ({ventas_min} ventas)")
    print(f"Total de productos vendidos: {total_ventas} productos")

# Crear tabla resumen con ventas por categoría en cada tienda
ventas_por_categoria = pd.DataFrame({
    'Tienda 1': tienda1['Categoría del Producto'].value_counts(),
    'Tienda 2': tienda2['Categoría del Producto'].value_counts(),
    'Tienda 3': tienda3['Categoría del Producto'].value_counts(),
    'Tienda 4': tienda4['Categoría del Producto'].value_counts()
}).fillna(0)
# Out:
# Ventas por categoría en Tienda 1:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
# Categoría más vendida: Muebles (465 ventas)
# Categoría menos vendida: Artículos para el hogar (171 ventas)
# Total de productos vendidos: 2359 productos
#
# Ventas por categoría en Tienda 2:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
# Categoría más vendida: Muebles (442 ventas)
# Categoría menos vendida: Artículos para el hogar (181 ventas)
# ...

# %%
# Crear gráfico de barras agrupadas
ax = ventas_por_categoria.plot(kind='bar', figsize=(10, 6))  # Guarda en 'ax'
plt.title('Ventas por Categoría en Cada Tienda')
ax.set_xlabel('')  # Esto ahora sí funciona porque 'ax' está definido correctamente
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Se puede observar que los productos electrónicos y los muebles son las categórias más vendidas en todas las tiendas. Por otro lado las categorias instrumentos musicales y articulos para el hogar son los menos vendidos. A pesar de que muebles es la categoria mas vendida, esta no representa el mayor ingreso, debido a que el precio de estos articulos son inferiores a otros como los equipos electrónicos.

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
tiendas = {
    'Tienda 1': tienda1,
    'Tienda 2': tienda2,
    'Tienda 3': tienda3,
    'Tienda 4': tienda4
}

costo_envio_promedio = {}

for nombre, df in tiendas.items():
    promedio = df['Costo de envío'].mean()
    costo_envio_promedio[nombre] = promedio
    # Mostrar costo de envío promedio de la tienda
    print(f"Costo de envío promedio en {nombre}: ${promedio:,.2f}")
# Out:
# Costo de envío promedio en Tienda 1: $26,018.61
# Costo de envío promedio en Tienda 2: $25,216.24
# Costo de envío promedio en Tienda 3: $24,805.68
# Costo de envío promedio en Tienda 4: $23,459.46

# %%
costo_envio_total = {}

for nombre, df in tiendas.items():
    total = df['Costo de envío'].sum()
    costo_envio_total[nombre] = total
    print(f"Costo de envío total en {nombre}: ${total:,.2f}")
# Out:
# Costo de envío total en Tienda 1: $61,377,900.00
# Costo de envío total en Tienda 2: $59,485,100.00
# Costo de envío total en Tienda 3: $58,516,600.00
# Costo de envío total en Tienda 4: $55,317,400.00

# %%
# Crear el gráfico de torta
plt.figure(figsize=(4, 4))
plt.pie(costo_envio_total.values(), labels=costo_envio_total.keys(), autopct='%1.1f%%', startangle=90)
plt.title('Distribución del Costo de Envío Total por Tienda')
plt.axis('equal')  # Para que el gráfico de torta sea circular
plt.show()

# %% [markdown]
# Podemos evidenciar que el costo de envio en todas las tiendas no es muy variado. A pesar que la tienda 1 es la que mas ingresos genera, tambien es la que tiene un mayor costo de envio , y esto es normal. Las demas tiendas mantienen su proporcion entre las ventas y el costo de envio.

# %% [markdown]
# ## Índice de eficiencia
# podemos calcular la eficiencia de la tienda , teniendo en cuenta los ingresos y el costo de envio.
#
# El índice de eficiencia se calcula con la siguiente fórmula:
#
# $$ \text{Índice de eficiencia} = \frac{\text{Ventas Totales}}{\text{Costo de Envío Total}} $$
#
#
# Se analizan las cuatro tiendas utilizando dos indicadores clave:
#
# Ingresos totales (ventas generadas por cada tienda).
#
# Costo total de envío (gastos en logística).
#
# Índice de eficiencia (relación entre ingresos y costos de envío, es decir, cuántos pesos se facturan por cada peso gastado en envío).texto en cursiva

# %%
# Calcular el índice de eficiencia (facturación / costo de envío total)
indice_eficiencia = {}
for nombre in costo_envio_total:
    ventas = facturaciones.get(nombre, 0)
    costo_envio = costo_envio_total[nombre]
    indice_eficiencia[nombre] = ventas / costo_envio if costo_envio != 0 else 0

# Imprimir el índice de eficiencia por tienda
for nombre, indice in indice_eficiencia.items():
    print(f"Índice de eficiencia de {nombre}: {indice:.2f}")

# Identificar la tienda con el índice más bajo
tienda_peor = min(indice_eficiencia, key=indice_eficiencia.get)
print(f"\nLa tienda con el índice de eficiencia más bajo es: {tienda_peor}")
# Out:
# Índice de eficiencia de Tienda 1: 18.75
# Índice de eficiencia de Tienda 2: 18.77
# Índice de eficiencia de Tienda 3: 18.76
# Índice de eficiencia de Tienda 4: 18.77
#
# La tienda con el índice de eficiencia más bajo es: Tienda 1

# %% [markdown]
# # **Representación:**
# La Tienda 1 tiene el índice de eficiencia más bajo, lo que significa que, en proporción, es la que menos dinero genera por cada peso invertido en envíos.
#
# Sin embargo, la diferencia con las demás tiendas es mínima (menos de 0.02 puntos), por lo tanto, no es una señal fuerte por sí sola para tomar una decisión drástica como cerrar o vender la tienda.
#
# Además, la Tienda 1 es la que más ingresos genera en total, lo cual es un punto muy positivo.

# %% [markdown]
# #Análisis del desempeño geográfico
#
# 1.   Elemento de la lista
# 2.   Elemento de la lista

# %%
tienda1['Tienda'] = 'Tienda 1'
tienda2['Tienda'] = 'Tienda 2'
tienda3['Tienda'] = 'Tienda 3'
tienda4['Tienda'] = 'Tienda 4'

# Unimos todas las tiendas en un solo DataFrame
df_tiendas = pd.concat([tienda1, tienda2, tienda3, tienda4], ignore_index=True)

# se asegura que no haya valores nulos en lat/lon
df_tiendas = df_tiendas.dropna(subset=['lat', 'lon'])

# Crear mapa centrado en el promedio de coordenadas
m = folium.Map(location=[df_tiendas['lat'].mean(), df_tiendas['lon'].mean()], zoom_start=6)

# Crear datos para el mapa de calor (lat, lon, intensidad = precio de venta)
heat_data = [[row['lat'], row['lon'], row['Precio']] for index, row in df_tiendas.iterrows()]

# Añadir el mapa de calor
HeatMap(heat_data, radius=13).add_to(m)

# %% [markdown]
# Podemos evidenciar cuales ciudades generan mas ingreso:
#
# 1.   Elemento de la lista
# 2.   Elemento de la lista

# %%
# Agrupar las ventas por ciudad y tienda
ventas_por_ciudad_tienda = df_tiendas.groupby(['Lugar de Compra', 'Tienda'])['Precio'].sum().unstack(fill_value=0)

# Sumar las ventas por ciudad (considerando todas las tiendas)
ventas_por_ciudad_total = ventas_por_ciudad_tienda.sum(axis=1)

# Ordenar por ventas totales (de mayor a menor)
ventas_por_ciudad_tienda_ordenado = ventas_por_ciudad_tienda.loc[ventas_por_ciudad_total.sort_values(ascending=False).index]

# Formatear los números para evitar notación científica y mostrar como valores monetarios
ventas_formateadas = ventas_por_ciudad_tienda_ordenado.applymap(lambda x: f"${x:,.2f}")

# Mostrar el DataFrame resultante
print("Ventas por ciudad y tienda (ordenadas):\n")
print(ventas_formateadas)
# Out:
# Ventas por ciudad y tienda (ordenadas):
#
# Tienda                  Tienda 1         Tienda 2         Tienda 3  \
# Lugar de Compra
# Bogotá           $440,005,000.00  $479,959,200.00  $475,562,100.00
# Medellín         $296,858,100.00  $297,246,700.00  $250,580,600.00
# Cali             $154,493,700.00  $118,257,600.00  $109,287,600.00
# Pereira           $56,214,300.00   $43,073,800.00   $62,504,500.00
# Barranquilla      $32,907,700.00   $27,741,300.00   $36,768,500.00
# Cartagena         $22,296,700.00   $21,548,300.00   $34,144,100.00
# Cúcuta            $37,879,500.00   $28,991,500.00   $25,165,500.00
# Bucaramanga       $17,579,200.00   $23,895,600.00   $23,538,900.00
# Riohacha          $18,512,700.00   $12,656,400.00   $19,025,900.00
# Leticia           $14,669,800.00   $16,159,000.00   $19,212,800.00
# Santa Marta       $13,198,300.00   $13,829,300.00   $12,854,300.00
# Pasto             $14,996,400.00   $12,800,100.00    $6,801,300.00
# ...

# %% [markdown]
# Como se puede evidenciar las ciudades más grandes de colombia, son las que más ingresos generan. Esto es común dado que en las ciudades mas grandes hay mas consumidores, hay mas ingresos , y por lo tanto, permiten un mayor consumo.

# %% [markdown]
# # Conclusión
#
# **¿qué tienda debería vender el Sr. Juan?**

# %%
import pandas as pd

def resumen_tienda(nombre, df):
    try:
        facturacion = df["Precio"].sum()
        calif = df["Calificación"].mean()
        envio = df["Costo de envío"].mean()

        # Suponiendo que "Cantidad de cuotas" representa volumen de venta
        mas_v = df.groupby("Producto")["Cantidad de cuotas"].sum().sort_values(ascending=False)
        mas_vendido = mas_v.index[0]
        mas_v_cant = mas_v.values[0]

        return {
            "Tienda": nombre,
            "Facturación Total": round(facturacion, 2),
            "Calificación Promedio": round(calif, 2),
            "Envío Promedio": round(envio, 2),
            "Producto Más Vendido": f"{mas_vendido} ({mas_v_cant})"
        }
    except KeyError as e:
        print(f"Error en la tienda {nombre}: falta la columna {e}")
        return {
            "Tienda": nombre,
            "Facturación Total": 0,
            "Calificación Promedio": 0,
            "Envío Promedio": 0,
            "Producto Más Vendido": "No disponible"
        }

# Crear resumen
resumen = [
    resumen_tienda("Tienda 1", tienda1),
    resumen_tienda("Tienda 2", tienda2),
    resumen_tienda("Tienda 3", tienda3),
    resumen_tienda("Tienda 4", tienda4),
]

# Mostrar tabla
resumen_df = pd.DataFrame(resumen)
display(resumen_df)

# Recomendación automática
mejor_fact = resumen_df.loc[resumen_df["Facturación Total"].idxmax()]
mejor_calif = resumen_df.loc[resumen_df["Calificación Promedio"].idxmax()]

print("\nRecomendación para el Sr. Juan:\n")
if mejor_fact["Tienda"] == mejor_calif["Tienda"]:
    print(
        f"Se recomienda que el Sr. Juan venda en {mejor_fact['Tienda']}, ya que tiene la mayor facturación "
        f"(${mejor_fact['Facturación Total']}) y también la mejor calificación promedio "
        f"({mejor_fact['Calificación Promedio']})."
    )
else:
    print(
        f"{mejor_fact['Tienda']} tiene la mayor facturación (${mejor_fact['Facturación Total']}), "
        f"mientras que {mejor_calif['Tienda']} tiene la mejor calificación promedio "
        f"({mejor_calif['Calificación Promedio']}).\n\n"
        f"Si el Sr. Juan busca maximizar ganancias, debería elegir {mejor_fact['Tienda']}.\n"
        f"Si prefiere enfocarse en reputación y experiencia del cliente, la mejor opción sería {mejor_calif['Tienda']}."
    )
# Out:
#      Tienda  Facturación Total  Calificación Promedio  Envío Promedio  \
# 0  Tienda 1       1.150880e+09                   3.98        26018.61
# 1  Tienda 2       1.116344e+09                   4.04        25216.24
# 2  Tienda 3       1.098020e+09                   4.05        24805.68
# 3  Tienda 4       1.038376e+09                   4.00        23459.46
#
#               Producto Más Vendido
# 0           Secadora de ropa (214)
# 1  Iniciando en programación (223)
# 2                  Bicicleta (191)
# 3    Dashboards con Power BI (196)
# Recomendación para el Sr. Juan:
#
# Tienda 1 tiene la mayor facturación ($1150880400.0), mientras que Tienda 3 tiene la mejor calificación promedio (4.05).
#
# Si el Sr. Juan busca maximizar ganancias, debería elegir Tienda 1.
# Si prefiere enfocarse en reputación y experiencia del cliente, la mejor opción sería Tienda 3.

# %% [markdown]
# # **Graficos**
# En estos 3 gráficos de barras te mostrare a continuación:
#
# **Una tabla comparativa bien ordenada.**
#
# **Una recomendación automática clara.**
#
# **Tres gráficos de barras para comparar: facturación, calificación y envío promedio.**
#
# **Facturación Total por tienda.**
#
# **Calificación promedio (0 a 5).**
#
# **Costo de envío promedio.**
#
# Todo lo que necesitas el Sr. Juan  visualmente para poder tomar una decisión inteligente.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from IPython.display import display, Markdown

# Función para resumir información de cada tienda
def resumen_tienda(nombre, df):
    facturacion = df["Precio"].sum()
    calificacion = df["Calificación"].mean()
    envio_promedio = df["Costo de envío"].mean()

    ventas_por_producto = df.groupby("Producto")["Cantidad de cuotas"].sum().sort_values(ascending=False)
    producto_mas_vendido = ventas_por_producto.index[0]
    cantidad_vendida = ventas_por_producto.values[0]

    return {
        "Tienda": nombre,
        "Facturación Total": round(facturacion, 2),
        "Calificación Promedio": round(calificacion, 2),
        "Envío Promedio": round(envio_promedio, 2),
        "Producto Más Vendido": f"{producto_mas_vendido} ({cantidad_vendida})"
    }

# Crear resumen para todas las tiendas
resumen = [
    resumen_tienda("Tienda 1", tienda1),
    resumen_tienda("Tienda 2", tienda2),
    resumen_tienda("Tienda 3", tienda3),
    resumen_tienda("Tienda 4", tienda4),
]

resumen_df = pd.DataFrame(resumen)

# Mostrar tabla comparativa
display(Markdown("### Tabla Comparativa de Tiendas"))
display(resumen_df)

# Recomendación automática
mejor_fact = resumen_df.loc[resumen_df["Facturación Total"].idxmax()]
mejor_calif = resumen_df.loc[resumen_df["Calificación Promedio"].idxmax()]

if mejor_fact["Tienda"] == mejor_calif["Tienda"]:
    recomendacion = (
        f"Se recomienda que el Sr. Juan venda en **{mejor_fact['Tienda']}**, ya que tiene la mayor facturación "
        f"(${mejor_fact['Facturación Total']}) y también la mejor calificación promedio "
        f"({mejor_fact['Calificación Promedio']})."
    )
else:
    recomendacion = (
        f"{mejor_fact['Tienda']} tiene la mayor facturación (${mejor_fact['Facturación Total']}), "
        f"mientras que {mejor_calif['Tienda']} tiene la mejor calificación promedio "
        f"({mejor_calif['Calificación Promedio']}).\n\n"
        f"Si el Sr. Juan busca maximizar ganancias, debería elegir **{mejor_fact['Tienda']}**.\n"
        f"Si prefiere enfocarse en reputación y experiencia del cliente, la mejor opción sería **{mejor_calif['Tienda']}**."
    )

display(Markdown(f"### Recomendación para el Sr. Juan\n{recomendacion}"))

# Configuración del estilo de los gráficos
sns.set(style="whitegrid")

# Crear gráficos comparativos
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# Gráfico: Facturación Total
sns.barplot(ax=axs[0], x="Tienda", y="Facturación Total", data=resumen_df, palette="Blues_d")
axs[0].set_title("Facturación Total")

# Gráfico: Calificación Promedio
sns.barplot(ax=axs[1], x="Tienda", y="Calificación Promedio", data=resumen_df, palette="Greens_d")
axs[1].set_title("Calificación Promedio")
axs[1].set_ylim(0, 5)

# Gráfico: Costo de Envío Promedio
sns.barplot(ax=axs[2], x="Tienda", y="Envío Promedio", data=resumen_df, palette="Oranges_d")
axs[2].set_title("Costo de Envío Promedio")

plt.tight_layout()
plt.show()
# Out:
# ### Tabla Comparativa de Tiendas
#      Tienda  Facturación Total  Calificación Promedio  Envío Promedio  \
# 0  Tienda 1       1.150880e+09                   3.98        26018.61
# 1  Tienda 2       1.116344e+09                   4.04        25216.24
# 2  Tienda 3       1.098020e+09                   4.05        24805.68
# 3  Tienda 4       1.038376e+09                   4.00        23459.46
#
#               Producto Más Vendido
# 0           Secadora de ropa (214)
# 1  Iniciando en programación (223)
# 2                  Bicicleta (191)
# 3    Dashboards con Power BI (196)
# ### Recomendación para el Sr. Juan
# Tienda 1 tiene la mayor facturación ($1150880400.0), mientras que Tienda 3 tiene la mejor calificación promedio (4.05).
#
# Si el Sr. Juan busca maximizar ganancias, debería elegir **Tienda 1**.
# Si prefiere enfocarse en reputación y experiencia del cliente, la mejor opción sería **Tienda 3**.
# <ipython-input-33-80a0f9cb1463>:66: FutureWarning:
#
# ...
